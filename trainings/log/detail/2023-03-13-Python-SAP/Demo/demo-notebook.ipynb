# %%
import pandas as pd

# %%
pd.read_csv('txns.csv', encoding='iso8859-1', delimiter=';', columns)
# Out:
#      AT66666666666666  \
# 0    AT66666666666666
# 1    AT66666666666666
# 2    AT66666666666666
# 3    AT66666666666666
# 4    AT66666666666666
# ..                ...
# 107  AT66666666666666
# 108  AT66666666666666
# 109  AT66666666666666
# 110  AT66666666666666
# 111  AT66666666666666
#
#     Bezahlung Karte                              MC/000009284|ORPHEUM BAR  2371  K002 28.02. 21:14|ORPHEUM BAR\\GRAZ\8020      ST  \
# 0    95111243                                     F...
# 1    Abbuchung Onlinebanking                      B...
# 2    Gutschrift Onlinebanking                     B...
# 3    Bezahlung Karte                              M...
# 4    9325008697                                   F...
# ..                                                 ...
# 107  Bezahlung Karte                              M...
# 108  Abbuchung Onlinebanking         000000144919 F...
# 109  339099446722187                              B...
# 110  Abbuchung Onlinebanking                      B...
# ...
